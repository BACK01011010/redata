# %% [markdown]
# # 数据采集爬虫

# %%
# 爬虫的法律问题

# %%
# 数据如何获取
# 使用前端选择器来获取，是其中比较常用的方法

# %%
import requests

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = 'https://tieba.baidu.com/f?dyTabStr=MCwxMiwzLDEsMiwxMyw3LDYsNSw5&fr=ala0&kw=%BB%AA%B1%B1%BF%C6%BC%BC%D1%A7%D4%BA&tpl=5'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# 获取页面中网页内容
response.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<!--STATUS OK-->\r\n<html>\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n    <link rel="search" type="application/opensearchdescription+xml" href="/tb/cms/content-search.xml" title="百度贴吧" />\r\n    \t<meta itemprop="dateUpdate" content="2024-12-30 21:54:24" />\n\n                <meta name="keywords" content="华北科技学院,华北地区高等院校,教育">\r\n        <meta name="description" content="本吧热帖: 1-来更一个长期贴，19级老年人对华科的印象和杂谈 2-这就是华科的菜鸟驿站啊 3-全丸辣哈哈哈哈 4-应大内外美食攻略 5-大一包红温的 6-请问学费在哪里交 7-有疑问，求帮助 8-拒绝霸凌，友好社交；劳逸结合，周六去看线下脱口秀开怀大笑一场吧 9-收书收书收书 10-课题组招生 11-【12-23】北区和中区的通行规定 12-家人们 转专业有懂的吗 13-寒假怎样才能留在学校？">\r\n        <title>华北科技学院吧-百度贴吧 </title>\r\n    \r\n    <link rel="stylesheet" href="//tb1.bdstatic.com/??/tb/static-common/style/tb.js/dialog_d30a0dc.css,/tb/static-common/lib/tbui/style/all_710c86c.css" />\n<link rel="stylesheet" href="//tb1.bdstatic.com/??/tb/_/index_02a41e4.css,/tb/_/bg_image_9c04eee.css,/tb/_/login_dialog_
# ...

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %% [markdown]
# # 解析库

# %%
from lxml import etree

# %%
html = etree.HTML(response.text)
html
# Out:
# <Element html at 0x20393060200>

# %%
# 获取title
titles = html.xpath('//*[@id="thread_list"]/li/div/div[2]/div[1]/div[1]/a/text()')
titles
# Out:
# ['请问学费在哪里交',
#  '有疑问，求帮助',
#  '拒绝霸凌，友好社交；劳逸结合，周六去看线下脱口秀开怀大笑一场吧',
#  '收书收书收书',
#  '课题组招生',
#  '【12-23】北区和中区的通行规定',
#  '家人们 转专业有懂的吗',
#  '寒假怎样才能留在学校？',
#  '大家自习都去哪里啊',
#  '求考研搭子',
#  '新闻专业的期末考试',
#  '找一个数学好的同学，想给孩子讲讲高中的数学。',
#  '【12-22】啊？关于天桥的是真的吗',
#  '校外人员能入校吗',
#  '新补办的饭卡多久才能进图书馆呀！！！好别扭',
#  '实训成绩算在学分绩里吗？还是过了就行',
#  '求国防教育考试资料',
#  '想问问这个学校转专业难吗',
#  '一些关于绩点的问题',
#  '忘记网上评教怎么办？',
#  '新生可以咨询问题',
#  '有没有期末考过计算机网络的学长学姐',
#  '开个帖子记录我在华科拍到的照片18级新生',
#  '其实年度最佳游戏给小机器人没什么问题',
#  '制图没听怎么自救',
#  '求助：华科对社会人士开放吗？',
#  '大一上高数期末考',
#  '求助老学长学姐',
#  '来更一个长期贴，19级老年人对华科的印象和杂谈',
#  '找个人帮我取快递（有偿）本人不再校',
#  '碎了，想找三战的数三搭子',
#  '表白墙咋加啊',
#  '求助一个名字',
#  '投稿爱民路',
#  '找游戏队友',
#  '【',
#  '】毕业十多年再回母校',
#  '量化扣多了会怎么样',
#  '有没有出红外四六耳机的',
#  '打印机维修',
#  '最近这城管也太严了吧',
#  '查寝的无敌了',
#  '啥时候放假',
#  '【多图预警】',
#  '有没有大二的学生告诉我一下数学成绩怎么计算啊？',
#  '新生开学必备篇',
#  '这是一篇2020年的新生指南（多图多字警告）',
#  '【华科吧迎新导航】2018年招生咨询专用贴',
#  '【吧务公告】2019年7月至8月房屋招租与物品交易贴',
#  '【吧务公告】2019年9月至10月房租招租与物品交易贴',
#  '【吧务公告】2019年11月至12月房屋招租与物品交易贴']

# %%
# 获取链接
links = html.xpath('//*[@id="thread_list"]/li/div/div[2]/div[1]/div[1]/a/@href')
links
# Out:
# ['/p/9373265740',
#  '/p/9366952209',
#  '/p/9373669577',
#  '/p/9373029877',
#  '/p/9371134838',
#  '/p/9353271434',
#  '/p/8757158570',
#  '/p/9343964523',
#  '/p/9330686421',
#  '/p/9285960664',
#  '/p/9333858493',
#  '/p/9340628179',
#  '/p/9352004001',
#  '/p/9181348069',
#  '/p/9359983578',
#  '/p/9357643754',
#  '/p/9354048193',
#  '/p/9064120277',
#  '/p/9352400463',
#  '/p/9354972836',
#  '/p/8505287222',
#  '/p/9354763628',
#  '/p/5985838632',
#  '/p/9336156749',
#  '/p/9344709595',
#  '/p/9335025485',
#  '/p/9348781962',
#  '/p/9156836918',
#  '/p/9345699435',
#  '/p/9349211539',
#  '/p/9351176787',
#  '/p/9034726935',
#  '/p/8508212503',
#  '/p/9344347081',
#  '/p/9343140558',
#  '/p/9160607720',
#  '/p/9336464047',
#  '/p/9336094002',
#  '/p/9336220147',
#  '/p/9333758908',
#  '/p/9263886962',
#  '/p/9330896004',
#  '/p/5774379091',
#  '/p/9323337895',
#  '/p/9101133741',
#  '/p/6802173582',
#  '/p/5765757857',
#  '/p/6180780168',
#  '/p/6243525040',
#  '/p/6319917497']

# %%
# 字符串拼接
a = '/p/9373265740'
url2 = 'https://tieba.baidu.com' + a
url2
# Out:
# 'https://tieba.baidu.com/p/9373265740'

# %%
# 练习2：
# 获取百度贴吧中的数据，
# 1，获取第一页的所有title内容，
# 2，获取打开每个内容的链接，
# 3，获取发布人的名字，
# 4，获取回复帖子时间
# 5. 保存数据为Excel文件。
